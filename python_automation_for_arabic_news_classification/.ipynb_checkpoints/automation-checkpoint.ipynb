# %%
# run_every_30min.py
# !pip install --upgrade certifi
import time
import datetime
import threading
import os
import my_script
# import process_excel  # Uncomment when ready
import nlp
WATCH_FOLDER = "my_data"
CHECK_INTERVAL = 5  # seconds between folder checks
def run_scraping_every_30min():
    """Run the scraping job every 30 minutes forever."""
    while True:
        print("\n⏰ Starting new 30-minute scraping cycle...")
        start_time = datetime.datetime.now()
        print(f"🕒 Script started at: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

        try:
            my_script.main()
        except Exception as e:
            print(f"❌ Error in scraping script: {e}")

        end_time = datetime.datetime.now()
        duration = end_time - start_time
        print(f"✅ Script finished at: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
        print(f"⏱️ Duration: {duration}")

        print("💤 Sleeping for 30 minutes...\n")
        time.sleep(30 * 60)  # sleep between runs (1800 seconds)

def delete_all_files(folder_path):
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        try:
            if os.path.isfile(file_path):
                os.remove(file_path)
               # print(f"Deleted: {file_path}")
        except Exception as e:
            print(f"Error deleting {file_path}: {e}")

def watch_folder_for_csv():
    delete_all_files(WATCH_FOLDER)
    """Continuously watch a folder for new Excel files and react."""
    print(f"👀 Watching folder:{ WATCH_FOLDER}")

    # Create folder if it doesn't exist
    os.makedirs(WATCH_FOLDER, exist_ok=True)
    seen_files = set(os.listdir(WATCH_FOLDER))
    while True:
        try:
            current_files = set(os.listdir(WATCH_FOLDER))
            new_files = current_files - seen_files

            for file in new_files:
                if file.lower().endswith(".csv"):
                    file_path = os.path.join(WATCH_FOLDER, file)
                    print(f"📂 New csv file detected: {file_path}")
                    try:
                        # process_csv.main(file_path)
                        nlp.main(file_path)
                        print(f"✅ (Simulated) Processed csv file: {file}")
                    except Exception as e:
                        print(f"❌ Error processing {file}: {e}")

            seen_files = current_files
            time.sleep(CHECK_INTERVAL)

        except Exception as e:
            print(f"⚠️ Folder watch error: {e}")
            time.sleep(10)


if __name__ == "__main__":
    # Start both threads (they run forever in parallel)
    scraping_thread = threading.Thread(target=run_scraping_every_30min, daemon=True)
    folder_thread = threading.Thread(target=watch_folder_for_csv, daemon=True)

    scraping_thread.start()
    folder_thread.start()

    print("🚀 Scraper and folder watcher started!\n")

    # Keep the main thread alive so daemon threads keep running
    while True:
        time.sleep(1)
# Out:
# Requirement already satisfied: certifi in c:\users\alnour-320\anaconda3\lib\site-packages (2025.11.12)
#
# ⏰ Starting new 30-minute scraping cycle...
# 🕒 Script started at: 2025-12-19 13:15:55
#
# 🚀 Starting scraping run...
# 🚀 Scraper and folder watcher started!
#
# 👀 Watching folder:my_data
# [INFO] Saved elbashayer.csv
# [WARN] Failed to fetch https://www.shorouknews.com/news/view.aspx?cdate=19122025&id=452cf20d-06da-43cb-a791-8ca6e5bfcb0c (attempt 1/3): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
%D8%A7%D8%B3%D8%AA%D8%AE%D8%AF%D9%85%D8%A7%D8%AA-%D9%84%D9%86-%D8%AA%D8%AA%D9%88%D9%82%D8%B9%D9%87%D8%A7-%D9%84%D8%A8%D9%82%D8%A7%D9%8A%D8%A7-%D8%A7%D9%84%D9%82%D9%87%D9%88%D8%A9
# [ERROR] Giving up on https://alwan.elwatannews.com/news/details/7379362/%D9%85%D8%AA%D8%B1%D9%85%D9%8A%D9%87%D8%A7%D8%B4-%D8%A8%D8%B9%D8%AF-%D9%85%D8%A7-%D8%AA%D8%B4%D8%B1%D8%A8%D9%87%D8%A7-5-%D8%A7%D8%B3%D8%AA%D8%AE%D8%AF%D9%85%D8%A7%D8%AA-%D9%84%D9%86-%D8%AA%D8%AA%D9%88%D9%82%D8%B9%D9%87%D8%A7-%D9%84%D8%A8%D9%82%D8%A7%D9%8A%D8%A7-%D8%A7%D9%84%D9%82%D9%87%D9%88%D8%A9 after 3 attempts.
# [INFO] Saved elwatan.csv
# 📂 New csv file detected: my_data\elwatan.csv
#
# 📂 Analyzing: my_data\elwatan.csv
# C:\Users\ALNOUR-320\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# ✅ Analysis complete for elwatan
#    - my_data\news_insights_output\elwatan_unigrams.csv
#    - my_data\news_insights_output\elwatan_ngrams.csv
#    - my_data\news_insights_output\elwatan_summary.csv
# ✅ (Simulated) Processed csv file: elwatan.csv
# [ERROR] masrielyoum section failed: HTTPConnectionPool(host='localhost', port=9493): Read timed out. (read timeout=120)
# [ERROR] youm7 section failed: Message: session not created: Chrome failed to start: crashed.
#   (session not created: DevToolsActivePort file doesn't exist)
#   (The process started from chrome location C:\Program Files\Google\Chrome\Application\chrome.exe is no longer running, so ChromeDriver is assuming that Chrome has crashed.)
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x10a12d3
# 	0x10a1314
# 	0xe8e6dd
# 	0xec4b37
# 	0xebfafa
# 	0xf07826
# 	0xf07047
# 	0xefb2e6
# 	0xecd321
# 	0xece1d4
# 	0x12f5314
# 	0x12f08cb
# 	0x130d1aa
# 	0x10bb1d8
# 	0x10c31dd
# 	0x10a95d8
# 	0x10a9799
# 	0x1093b28
# 	0x75275d49
# 	0x76eed5db
# 	0x76eed561
# Error sending stats to Plausible: error sending request for url (https://plausible.io/api/event)
# [ERROR] masrawy section failed: Message: session not created: Chrome failed to start: crashed.
#   (session not created: DevToolsActivePort file doesn't exist)
#   (The process started from chrome location C:\Program Files\Google\Chrome\Application\chrome.exe is no longer running, so ChromeDriver is assuming that Chrome has crashed.)
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff78d3d88e5
# 	0x7ff78d3d8940
# 	0x7ff78d1b165d
# 	0x7ff78d1f02a0
# 	0x7ff78d1eb7dd
# 	0x7ff78d240186
# 	0x7ff78d23fa06
# 	0x7ff78d1fac29
# 	0x7ff78d1fba93
# 	0x7ff78d6f0640
# 	0x7ff78d6eaf80
# 	0x7ff78d7096e6
# 	0x7ff78d3f5de4
# 	0x7ff78d3fed8c
# 	0x7ff78d3e2004
# 	0x7ff78d3e21b5
# 	0x7ff78d3c7ee2
# 	0x7ffdd03fe8d7
# 	0x7ffdd188c53c
#
#
# ✅ Script finished. All reachable sites processed.
# ✅ Script finished at: 2025-12-19 13:20:38
# ⏱️ Duration: 0:04:42.790304
# 💤 Sleeping for 30 minutes...

# %%
# !pip install --upgrade certifi
