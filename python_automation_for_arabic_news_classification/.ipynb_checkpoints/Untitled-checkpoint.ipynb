# %%
import pandas as pd
x=pd.read_csv("my_data/elmasrielyoum.csv")
x.head()
# Out:
#    Title                                               Link      website  \
# 0    NaN  https://www.almasryalyoum.com/news/details/359...  masrielyoum
# 1    NaN  https://www.almasryalyoum.com/news/details/359...  masrielyoum
# 2    NaN  https://www.almasryalyoum.com/news/details/359...  masrielyoum
# 3    NaN  https://www.almasryalyoum.com/news/details/359...  masrielyoum
# 4    NaN  https://www.almasryalyoum.com/news/details/359...  masrielyoum
#
#                                         Article_Text
# 0  قال الدكتور مصطفى مدبولي، رئيس مجلس الوزراء، إ...
# 1  أخبار متعلقة\n«سقطت نيويورك واُنتخب عدونا مؤيد...
# 2  في نصف نهائي السوبر المصري، يبحث الكثيرون من ع...
# 3  أخبار متعلقة\n«المحامين»: لا نعلم هوية المصري ...
# 4  استقر\n6-11-2025 مساءً، بعد ارتفاع\nأثناء التع...

# %%
x["True_Label"]='REAL'

# %%
x.to_csv("labeled_data/labeled_elmasrielyoum.csv",index=False, encoding='utf-8-sig')
